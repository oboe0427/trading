# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

cwd = Path.cwd()

# 이 노트북이 notebooks 폴더 안에 있다고 가정
if cwd.name == "notebooks":
    PROJECT_ROOT = cwd.parent
    NOTEBOOK_DIR = cwd
else:
    PROJECT_ROOT = cwd
    NOTEBOOK_DIR = PROJECT_ROOT / "notebooks"

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("PROJECT_ROOT:", PROJECT_ROOT)

# src 임포트 위해 프로젝트 루트 추가
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))
# Out:
# NOTEBOOK_DIR: /Users/gy/projects/trading-project/notebooks
# PROJECT_ROOT: /Users/gy/projects/trading-project

# %%
from src.preprocess.mt5_prep import (
    prepare_mt5_with_sessions_ktr_candles,
    prepare_mt5_with_sessions_and_ktr,  # 같은 함수, 이름만 다름
    add_candle_features,
    add_candle_pattern_column,
)

DATA_PATH = PROJECT_ROOT / "data_raw" / "usdjpym5_indicators_0529-1204.csv"
DATA_PATH
# Out:
# PosixPath('/Users/gy/projects/trading-project/data_raw/usdjpym5_indicators_0529-1204.csv')

# %%
df = prepare_mt5_with_sessions_ktr_candles(DATA_PATH)

df.head()
# Out:
#          Date   Time     Open     High      Low    Close  TickVolume  \
# 0  2025.05.29  09:00  144.886  145.003  144.877  144.978         457
# 1  2025.05.29  09:05  144.977  145.187  144.974  145.165         520
# 2  2025.05.29  09:10  145.165  145.343  145.164  145.322         838
# 3  2025.05.29  09:15  145.322  145.457  145.319  145.370         913
# 4  2025.05.29  09:20  145.370  145.473  145.359  145.468         703
#
#     bbpb_20    bbpb_4    bbw_20  ...  is_bear  candle_type  sma20  sma120  \
# 0  1.255560  0.704077  0.162469  ...        0    long_bull    NaN     NaN
# 1  1.379438  0.707715  0.270177  ...        0    long_bull    NaN     NaN
# 2  1.314308  0.699726  0.400501  ...        0    long_bull    NaN     NaN
# 3  1.172445  0.673778  0.502236  ...        0   inv_hammer    NaN     NaN
# 4  1.127976  0.631375  0.605851  ...        0    long_bull    NaN     NaN
#
#    s_l_diff  ma_bull  ma_bear  golden_cross dead_cross ma_cross
# ...

# %%
OUT_PATH = PROJECT_ROOT / "data_proc" / f"{DATA_PATH.stem}_prep.csv"
OUT_PATH.parent.mkdir(parents=True, exist_ok=True)

df.to_csv(OUT_PATH, index=False)
OUT_PATH
# Out:
# PosixPath('/Users/gy/projects/trading-project/data_proc/usdjpym5_indicators_0529-1204_prep.csv')
